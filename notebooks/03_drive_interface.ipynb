# %% [markdown]
# # Interacting with DRIVE through the DriveInterface

# %%
# %load_ext autoreload
# %autoreload 2

# %%
from eeclient.helpers import get_sepal_headers_from_auth
from sepal_ui.scripts.drive_interface import GDriveInterface
import logging
import os
from eeclient.client import EESession

# %%
logger = logging.getLogger("sepalui")
logger.setLevel(logging.INFO)
console_handler = logging.StreamHandler()
logger.addHandler(console_handler)

# %% [markdown]
# # Initialize GEE Interface from sepal headers

# %%
# Store these environment variables in your system
sepal_username = os.getenv("SEPAL_USER")
sepal_password = os.getenv("SEPAL_PASSWORD")
sepal_host = "sepal.io"

sepal_headers = get_sepal_headers_from_auth(sepal_username, sepal_password, sepal_host)

# %%
drive_interface = GDriveInterface(sepal_headers=sepal_headers)

# %% [markdown]
# ## Available methods

# %%
# download_file,
# get_items,
# download_file,
# delete_file,
# download_from_task_file

# %%
drive_interface.get_items();
